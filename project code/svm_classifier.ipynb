# %%
import numpy as np
import pandas as pd
import copy
from pandas import read_csv
filename='C:/Users/Chimata/Desktop/mlfinalyearproject/studentdetailsfinal.csv'
data = read_csv(filename)
data.head(5)
# Out:
#    year branch gender type  tenth  twelve higher_education    take_notes  \
# 0     4    CSE   Male    H   93.0    93.0            Maybe            No
# 1     4    CSE   Male    H   97.0    97.6            Maybe  Occasionally
# 2     4    CSE   Male    D   88.0    94.2            Maybe  Occasionally
# 3     4    CSE   Male    D   88.0    96.7            Maybe           Yes
# 4     4    CSE   Male    H   97.0    93.5               No            No
#
#      prefer_tostudy  hoursstudy time_relaxing  \
# 0  Just before exam           0      >5 hours
# 1             Daily           1     2-5 hours
# 2  Just before exam           0      >5 hours
# 3             Daily           2     2-5 hours
# 4  Just before exam           0      >5 hours
#
#                                  studymode active_backlogs  backlog_history  \
# 0                         Online Tutorials       4 & above                6
# 1  Online Tutorials, Class notes, Textbook               0                0
# ...

# %%
data.shape
# Out:
# (562, 20)

# %%
data.shape
# Out:
# (562, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 562 entries, 0 to 561
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    562 non-null    int64
#  1   branch                  562 non-null    object
#  2   gender                  562 non-null    object
#  3   type                    562 non-null    object
#  4   tenth                   562 non-null    float64
#  5   twelve                  562 non-null    float64
#  6   higher_education        562 non-null    object
#  7   take_notes              562 non-null    object
#  8   prefer_tostudy          562 non-null    object
#  9   hoursstudy              562 non-null    int64
#  10  time_relaxing           562 non-null    object
#  11  studymode               562 non-null    object
#  12  active_backlogs         562 non-null    object
#  13  backlog_history         562 non-null    int64
# ...

# %%
data.loc[data['tenth'] <=10, 'tenth'] = data['tenth']*10

# %%
data.loc[data['twelve'] <=10, 'twelve'] = data['twelve']*10

# %%
data.loc[data['twelve'] >100, 'twelve'] = data['twelve']/10

# %%
data
# Out:
#      year branch gender type  tenth  twelve higher_education    take_notes  \
# 0       4    CSE   Male    H   93.0    93.0            Maybe            No
# 1       4    CSE   Male    H   97.0    97.6            Maybe  Occasionally
# 2       4    CSE   Male    D   88.0    94.2            Maybe  Occasionally
# 3       4    CSE   Male    D   88.0    96.7            Maybe           Yes
# 4       4    CSE   Male    H   97.0    93.5               No            No
# ..    ...    ...    ...  ...    ...     ...              ...           ...
# 557     2  Other   Male    D   90.0    80.0            Maybe  Occasionally
# 558     1    MEE   Male    D   98.0    97.0               No            No
# 559     3    EEE   Male    H   89.0    89.0               No           Yes
# 560     3    ECE   Male    H   89.0    90.0              Yes            No
# 561     1    ECE   Male    D   83.0    91.0               No            No
#
#        prefer_tostudy  hoursstudy time_relaxing  \
# ...

# %%
unique=data.nunique()
print(unique)
# Out:
# year                        4
# branch                      6
# gender                      2
# type                        2
# tenth                      60
# twelve                    132
# higher_education            3
# take_notes                  3
# prefer_tostudy              2
# hoursstudy                  4
# time_relaxing               3
# studymode                   7
# active_backlogs             5
# backlog_history            19
# participate_activities      3
# attendance                  6
# cgpa                      215
# cgpaup                    201
# backlog                     5
# grade                       5
# dtype: int64

# %%
data.isnull().any().sum()
# Out:
# 0

# %%
data.year.value_counts()
# Out:
# 4    273
# 3    109
# 1    102
# 2     78
# Name: year, dtype: int64

# %%
data.branch.value_counts()
# Out:
# CSE      257
# ECE      122
# Other     68
# MEE       52
# EEE       38
# EIE       25
# Name: branch, dtype: int64

# %%
data=pd.get_dummies(data,columns=['branch'],drop_first=True)
data.head(5)
# Out:
#    year gender type  tenth  twelve higher_education    take_notes  \
# 0     4   Male    H   93.0    93.0            Maybe            No
# 1     4   Male    H   97.0    97.6            Maybe  Occasionally
# 2     4   Male    D   88.0    94.2            Maybe  Occasionally
# 3     4   Male    D   88.0    96.7            Maybe           Yes
# 4     4   Male    H   97.0    93.5               No            No
#
#      prefer_tostudy  hoursstudy time_relaxing  ... attendance  cgpa  cgpaup  \
# 0  Just before exam           0      >5 hours  ...      80-90  5.00    5.00
# 1             Daily           1     2-5 hours  ...   above 90  9.27    9.27
# 2  Just before exam           0      >5 hours  ...      80-90  6.20    6.20
# 3             Daily           2     2-5 hours  ...   above 90  7.36    7.36
# 4  Just before exam           0      >5 hours  ...   above 90  8.06    8.06
#
#   backlog          grade  branch_ECE  branch_EEE  branch_EIE branch_MEE  \
# ...

# %%
data.gender.value_counts()
# Out:
# Male      349
# Female    213
# Name: gender, dtype: int64

# %%
data=pd.get_dummies(data,columns=['gender','type','studymode'],drop_first=True)
data.head(5)
# Out:
#    year  tenth  twelve higher_education    take_notes    prefer_tostudy  \
# 0     4   93.0    93.0            Maybe            No  Just before exam
# 1     4   97.0    97.6            Maybe  Occasionally             Daily
# 2     4   88.0    94.2            Maybe  Occasionally  Just before exam
# 3     4   88.0    96.7            Maybe           Yes             Daily
# 4     4   97.0    93.5               No            No  Just before exam
#
#    hoursstudy time_relaxing active_backlogs  backlog_history  ... branch_MEE  \
# 0           0      >5 hours       4 & above                6  ...          0
# 1           1     2-5 hours               0                0  ...          0
# 2           0      >5 hours               0                4  ...          0
# 3           2     2-5 hours               0                0  ...          0
# 4           0      >5 hours               0                0  ...          0
#
# ...

# %%
data.higher_education.value_counts()
# Out:
# Yes      261
# Maybe    203
# No        98
# Name: higher_education, dtype: int64

# %%
data['higher_education'].replace(['Maybe','No','Yes'],[1,0,2],inplace=True)
data.head(5)
# Out:
#    year  tenth  twelve  higher_education    take_notes    prefer_tostudy  \
# 0     4   93.0    93.0                 1            No  Just before exam
# 1     4   97.0    97.6                 1  Occasionally             Daily
# 2     4   88.0    94.2                 1  Occasionally  Just before exam
# 3     4   88.0    96.7                 1           Yes             Daily
# 4     4   97.0    93.5                 0            No  Just before exam
#
#    hoursstudy time_relaxing active_backlogs  backlog_history  ... branch_MEE  \
# 0           0      >5 hours       4 & above                6  ...          0
# 1           1     2-5 hours               0                0  ...          0
# 2           0      >5 hours               0                4  ...          0
# 3           2     2-5 hours               0                0  ...          0
# 4           0      >5 hours               0                0  ...          0
#
# ...

# %%
data.take_notes.value_counts()
# Out:
# Yes             276
# Occasionally    198
# No               88
# Name: take_notes, dtype: int64

# %%
data['take_notes'].replace(['Occasionally','No','Yes'],[1,0,2],inplace=True)
data.head(5)
# Out:
#    year  tenth  twelve  higher_education  take_notes    prefer_tostudy  \
# 0     4   93.0    93.0                 1           0  Just before exam
# 1     4   97.0    97.6                 1           1             Daily
# 2     4   88.0    94.2                 1           1  Just before exam
# 3     4   88.0    96.7                 1           2             Daily
# 4     4   97.0    93.5                 0           0  Just before exam
#
#    hoursstudy time_relaxing active_backlogs  backlog_history  ... branch_MEE  \
# 0           0      >5 hours       4 & above                6  ...          0
# 1           1     2-5 hours               0                0  ...          0
# 2           0      >5 hours               0                4  ...          0
# 3           2     2-5 hours               0                0  ...          0
# 4           0      >5 hours               0                0  ...          0
#
#   branch_Other  gender_Male  type_H  studymode_Class notes, Textbook  \
# ...

# %%
data.prefer_tostudy.value_counts()
# Out:
# Just before exam    411
# Daily               151
# Name: prefer_tostudy, dtype: int64

# %%
data['prefer_tostudy'].replace(['Just before exam','Daily'],[1,2],inplace=True)
data.head(5)
# Out:
#    year  tenth  twelve  higher_education  take_notes  prefer_tostudy  \
# 0     4   93.0    93.0                 1           0               1
# 1     4   97.0    97.6                 1           1               2
# 2     4   88.0    94.2                 1           1               1
# 3     4   88.0    96.7                 1           2               2
# 4     4   97.0    93.5                 0           0               1
#
#    hoursstudy time_relaxing active_backlogs  backlog_history  ... branch_MEE  \
# 0           0      >5 hours       4 & above                6  ...          0
# 1           1     2-5 hours               0                0  ...          0
# 2           0      >5 hours               0                4  ...          0
# 3           2     2-5 hours               0                0  ...          0
# 4           0      >5 hours               0                0  ...          0
#
#   branch_Other  gender_Male  type_H  studymode_Class notes, Textbook  \
# ...

# %%
data.hoursstudy.value_counts()
# Out:
# 1    244
# 0    151
# 2    119
# 3     48
# Name: hoursstudy, dtype: int64

# %%
data.time_relaxing.value_counts()
# Out:
# 2-5 hours    283
# >5 hours     215
# <2 hours      64
# Name: time_relaxing, dtype: int64

# %%
data['time_relaxing'].replace(['>5 hours','2-5 hours','<2 hours'],[1,2,3],inplace=True)
data.head(5)
# Out:
#    year  tenth  twelve  higher_education  take_notes  prefer_tostudy  \
# 0     4   93.0    93.0                 1           0               1
# 1     4   97.0    97.6                 1           1               2
# 2     4   88.0    94.2                 1           1               1
# 3     4   88.0    96.7                 1           2               2
# 4     4   97.0    93.5                 0           0               1
#
#    hoursstudy  time_relaxing active_backlogs  backlog_history  ... branch_MEE  \
# 0           0              1       4 & above                6  ...          0
# 1           1              2               0                0  ...          0
# 2           0              1               0                4  ...          0
# 3           2              2               0                0  ...          0
# 4           0              1               0                0  ...          0
#
#   branch_Other  gender_Male  type_H  studymode_Class notes, Textbook  \
# ...

# %%
data.active_backlogs.value_counts()
# Out:
# 0            460
# 4 & above     36
# 1             33
# 2             21
# 3             12
# Name: active_backlogs, dtype: int64

# %%
data['active_backlogs'].replace(['4 & above','0','1','2','3'],[4,0,1,2,3],inplace=True)
data.head(5)
# Out:
#    year  tenth  twelve  higher_education  take_notes  prefer_tostudy  \
# 0     4   93.0    93.0                 1           0               1
# 1     4   97.0    97.6                 1           1               2
# 2     4   88.0    94.2                 1           1               1
# 3     4   88.0    96.7                 1           2               2
# 4     4   97.0    93.5                 0           0               1
#
#    hoursstudy  time_relaxing  active_backlogs  backlog_history  ...  \
# 0           0              1                4                6  ...
# 1           1              2                0                0  ...
# 2           0              1                0                4  ...
# 3           2              2                0                0  ...
# 4           0              1                0                0  ...
#
#   branch_MEE branch_Other  gender_Male  type_H  \
# 0          0            0            1       1
# ...

# %%
data.backlog_history.value_counts()
# Out:
# 0     422
# 1      45
# 2      15
# 3      12
# 4      12
# 5      12
# 7      10
# 6       8
# 12      5
# 8       5
# 10      4
# 11      3
# 9       2
# 18      2
# 19      1
# 13      1
# 14      1
# 16      1
# 21      1
# Name: backlog_history, dtype: int64

# %%
data.participate_activities.value_counts()
# Out:
# Occasionally    346
# Always          145
# Never            71
# Name: participate_activities, dtype: int64

# %%
data['participate_activities'].replace(['Occasionally','Always','Never'],[1,2,0],inplace=True)
data.head(5)
# Out:
#    year  tenth  twelve  higher_education  take_notes  prefer_tostudy  \
# 0     4   93.0    93.0                 1           0               1
# 1     4   97.0    97.6                 1           1               2
# 2     4   88.0    94.2                 1           1               1
# 3     4   88.0    96.7                 1           2               2
# 4     4   97.0    93.5                 0           0               1
#
#    hoursstudy  time_relaxing  active_backlogs  backlog_history  ...  \
# 0           0              1                4                6  ...
# 1           1              2                0                0  ...
# 2           0              1                0                4  ...
# 3           2              2                0                0  ...
# 4           0              1                0                0  ...
#
#    branch_MEE branch_Other  gender_Male  type_H  \
# 0           0            0            1       1
# ...

# %%
data.attendance.value_counts()
# Out:
# 80-90 %       227
# above 90 %    158
# 75-80 %       155
# 80-90          11
# above 90       10
# 75-80           1
# Name: attendance, dtype: int64

# %%
data['attendance'].replace(['75-80 %','80-90 %','above 90 %','75-80','80-90','above 90'],[0,1,2,0,1,2],inplace=True)
data.head(5)
# Out:
#    year  tenth  twelve  higher_education  take_notes  prefer_tostudy  \
# 0     4   93.0    93.0                 1           0               1
# 1     4   97.0    97.6                 1           1               2
# 2     4   88.0    94.2                 1           1               1
# 3     4   88.0    96.7                 1           2               2
# 4     4   97.0    93.5                 0           0               1
#
#    hoursstudy  time_relaxing  active_backlogs  backlog_history  ...  \
# 0           0              1                4                6  ...
# 1           1              2                0                0  ...
# 2           0              1                0                4  ...
# 3           2              2                0                0  ...
# 4           0              1                0                0  ...
#
#    branch_MEE  branch_Other  gender_Male  type_H  \
# 0           0             0            1       1
# ...

# %%
data.active_backlogs.value_counts()
# Out:
# 0    460
# 4     36
# 1     33
# 2     21
# 3     12
# Name: active_backlogs, dtype: int64

# %%
data.grade.value_counts()
# Out:
# Good             172
# Excellent        138
# Average          120
# Low               88
# Below_average     44
# Name: grade, dtype: int64

# %%
data=pd.get_dummies(data,columns=['year'],drop_first=True)

# %%
data.tail(10)
# Out:
#      tenth  twelve  higher_education  take_notes  prefer_tostudy  hoursstudy  \
# 552   90.0    88.0                 2           2               1           2
# 553   83.0    63.0                 1           2               2           2
# 554   90.0    88.0                 2           2               1           2
# 555   95.0    85.0                 1           1               2           0
# 556   86.0    88.0                 0           2               1           0
# 557   90.0    80.0                 1           1               1           1
# 558   98.0    97.0                 0           0               2           1
# 559   89.0    89.0                 0           2               1           1
# 560   89.0    90.0                 2           0               2           0
# 561   83.0    91.0                 0           0               1           0
#
#      time_relaxing  active_backlogs  backlog_history  participate_activities  \
# ...

# %%
data.shape
# Out:
# (562, 31)

# %%
data.dtypes
# Out:
# tenth                                                float64
# twelve                                               float64
# higher_education                                       int64
# take_notes                                             int64
# prefer_tostudy                                         int64
# hoursstudy                                             int64
# time_relaxing                                          int64
# active_backlogs                                        int64
# backlog_history                                        int64
# participate_activities                                 int64
# attendance                                             int64
# cgpa                                                 float64
# cgpaup                                               float64
# backlog                                                int64
# grade                                                 object
# ...

# %%
#svm classifier

# %%
import pandas as pd
import numpy as np

# %%
X=data[['year_2','year_3','year_4','tenth','twelve','higher_education','take_notes','prefer_tostudy','hoursstudy','time_relaxing','backlog','backlog_history','participate_activities','attendance','branch_ECE','branch_EEE','branch_EIE','branch_MEE','branch_Other','gender_Male','type_H','studymode_Class notes, Textbook','studymode_Online Tutorials','studymode_Online Tutorials, Class notes','studymode_Online Tutorials, Class notes, Textbook','studymode_Textbook','studymode_Online Tutorials, Textbook','cgpaup']]
Y=data['grade']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
#randomsearchcv
from scipy.stats import randint
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn import svm

# %%
clf = svm.SVC() 
clf.fit(X_train, Y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
param_dist={"kernel":["linear","poly","rbf"],"gamma":["auto"]}

# %%
tree=svm.SVC()
tree_cv=RandomizedSearchCV(tree,param_dist,cv=10)

# %%
tree_cv.fit(X_train,Y_train)
# Out:
# C:\Users\Chimata\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:281: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# RandomizedSearchCV(cv=10, error_score=nan,
#                    estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                                  class_weight=None, coef0=0.0,
#                                  decision_function_shape='ovr', degree=3,
#                                  gamma='scale', kernel='rbf', max_iter=-1,
#                                  probability=False, random_state=None,
#                                  shrinking=True, tol=0.001, verbose=False),
#                    iid='deprecated', n_iter=10, n_jobs=None,
#                    param_distributions={'gamma': ['auto'],
#                                         'kernel': ['linear', 'poly', 'rbf']},
# ...

# %%
print("Tuned Parametres:{}".format(tree_cv.best_params_))
# Out:
# Tuned Parametres:{'kernel': 'linear', 'gamma': 'auto'}

# %%
from sklearn import svm
clf = svm.SVC(kernel='linear',gamma='auto') 
clf.fit(X_train, Y_train)
Y_pred = clf.predict(X_test)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.8761061946902655

# %%
from sklearn.model_selection import cross_val_score
clf = svm.SVC(kernel='linear',gamma='auto')
scores = cross_val_score(clf, X, Y, cv=10, scoring='accuracy')
print(scores)
# Out:
# [0.85964912 0.85964912 0.92857143 0.89285714 0.83928571 0.94642857
#  0.83928571 0.78571429 0.82142857 0.92857143]

# %%
print(scores.mean())
# Out:
# 0.8701441102756892

# %%
#univariate selection

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

X=data[['year_2','year_3','year_4','tenth','twelve','higher_education','take_notes','prefer_tostudy','hoursstudy','time_relaxing','backlog','backlog_history','participate_activities','attendance','branch_ECE','branch_EEE','branch_EIE','branch_MEE','branch_Other','gender_Male','type_H','studymode_Class notes, Textbook','studymode_Online Tutorials','studymode_Online Tutorials, Class notes','studymode_Online Tutorials, Class notes, Textbook','studymode_Textbook','studymode_Online Tutorials, Textbook','cgpaup']]
Y=data['grade']
bestfeatures = SelectKBest(score_func=chi2, k=15)
fit = bestfeatures.fit(X,Y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  
print(featureScores.nlargest(15,'Score'))
# Out:
#                                                 Specs        Score
# 11                                    backlog_history  1755.794817
# 10                                            backlog  1058.284596
# 27                                             cgpaup   101.073534
# 4                                              twelve    45.258407
# 3                                               tenth    37.284463
# 13                                         attendance    28.291198
# 25                                 studymode_Textbook    19.595628
# 6                                          take_notes    13.800074
# 14                                         branch_ECE    11.392317
# 19                                        gender_Male    10.304561
# 2                                              year_4     9.274072
# 1                                              year_3     8.306396
# 0                                              year_2     6.118475
# ...

# %%
#univariate selection
X=data[['year_4','year_3','tenth','twelve','hoursstudy','backlog','backlog_history','attendance','take_notes','studymode_Textbook','branch_ECE','branch_MEE','gender_Male','studymode_Online Tutorials, Class notes, Textbook','cgpaup']]
Y=data['grade']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
#randomsearchcv
from scipy.stats import randint
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn import svm

# %%
clf = svm.SVC() 
clf.fit(X_train, Y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
param_dist={"kernel":["linear","poly","rbf"],"gamma":["auto"]}

# %%
tree=svm.SVC()
tree_cv=RandomizedSearchCV(tree,param_dist,cv=10)

# %%
tree_cv.fit(X_train,Y_train)
# Out:
# C:\Users\Chimata\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:281: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# RandomizedSearchCV(cv=10, error_score=nan,
#                    estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                                  class_weight=None, coef0=0.0,
#                                  decision_function_shape='ovr', degree=3,
#                                  gamma='scale', kernel='rbf', max_iter=-1,
#                                  probability=False, random_state=None,
#                                  shrinking=True, tol=0.001, verbose=False),
#                    iid='deprecated', n_iter=10, n_jobs=None,
#                    param_distributions={'gamma': ['auto'],
#                                         'kernel': ['linear', 'poly', 'rbf']},
# ...

# %%
print("Tuned Parametres:{}".format(tree_cv.best_params_))
# Out:
# Tuned Parametres:{'kernel': 'linear', 'gamma': 'auto'}

# %%
from sklearn import svm
clf = svm.SVC(kernel='linear',gamma='auto')
clf.fit(X_train, Y_train)
Y_pred = clf.predict(X_test)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.8584070796460177

# %%
from sklearn.model_selection import cross_val_score
clf = svm.SVC(kernel='linear',gamma='auto')
scores = cross_val_score(clf, X, Y, cv=10, scoring='accuracy')
print(scores)
# Out:
# [0.89473684 0.9122807  0.875      0.89285714 0.83928571 0.92857143
#  0.89285714 0.875      0.80357143 0.875     ]

# %%
print(scores.mean())
# Out:
# 0.8789160401002507

# %%
#feature importance

# %%
import pandas as pd
import numpy as np
X=data[['year_2','year_3','year_4','tenth','twelve','higher_education','take_notes','prefer_tostudy','hoursstudy','time_relaxing','backlog','backlog_history','participate_activities','attendance','branch_ECE','branch_EEE','branch_EIE','branch_MEE','branch_Other','gender_Male','type_H','studymode_Class notes, Textbook','studymode_Online Tutorials','studymode_Online Tutorials, Class notes','studymode_Online Tutorials, Class notes, Textbook','studymode_Textbook','studymode_Online Tutorials, Textbook','cgpaup']]
Y=data['grade']
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,Y)
print(model.feature_importances_) 
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(15).plot(kind='barh')
plt.show()
# Out:
# [0.01338208 0.01488996 0.01740099 0.05293891 0.05124572 0.0352196
#  0.02877376 0.01609333 0.03091309 0.02823093 0.1130234  0.06264658
#  0.0323637  0.03146294 0.01687154 0.010786   0.00795258 0.01044489
#  0.01313692 0.01986235 0.02358054 0.01365012 0.01295252 0.01768589
#  0.01512287 0.01289168 0.00599977 0.29047734]

# %%
#feature importance selection
X=data[['tenth','twelve','higher_education','take_notes','hoursstudy','time_relaxing','backlog','backlog_history','participate_activities','attendance','branch_ECE','gender_Male','type_H','studymode_Online Tutorials, Class notes','cgpaup']]
Y=data['grade']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
#randomsearchcv
from scipy.stats import randint
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn import svm

# %%
clf = svm.SVC() 
clf.fit(X_train, Y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
param_dist={"kernel":["linear","poly","rbf"],"gamma":["auto"]}

# %%
tree=svm.SVC()
tree_cv=RandomizedSearchCV(tree,param_dist,cv=10)

# %%
tree_cv.fit(X_train,Y_train)
# Out:
# C:\Users\Chimata\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:281: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# RandomizedSearchCV(cv=10, error_score=nan,
#                    estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                                  class_weight=None, coef0=0.0,
#                                  decision_function_shape='ovr', degree=3,
#                                  gamma='scale', kernel='rbf', max_iter=-1,
#                                  probability=False, random_state=None,
#                                  shrinking=True, tol=0.001, verbose=False),
#                    iid='deprecated', n_iter=10, n_jobs=None,
#                    param_distributions={'gamma': ['auto'],
#                                         'kernel': ['linear', 'poly', 'rbf']},
# ...

# %%
print("Tuned Parametres:{}".format(tree_cv.best_params_))
# Out:
# Tuned Parametres:{'kernel': 'poly', 'gamma': 'auto'}

# %%
from sklearn import svm
clf = svm.SVC(kernel='poly',degree=4,gamma='auto')
clf.fit(X_train, Y_train)
Y_pred = clf.predict(X_test)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.9026548672566371

# %%
from sklearn.model_selection import cross_val_score
clf = svm.SVC(kernel='poly',degree=4,gamma='auto')
scores = cross_val_score(clf, X, Y, cv=10, scoring='accuracy')
print(scores)
# Out:
# [0.89473684 0.92982456 0.92857143 0.92857143 0.85714286 0.92857143
#  0.82142857 0.85714286 0.85714286 0.94642857]

# %%
print(scores.mean())
# Out:
# 0.8949561403508772
